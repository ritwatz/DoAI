# %%
pip install face_recognition

# %%
import face_recognition
known_image = face_recognition.load_image_file("messi.jpg")
face_locations = face_recognition.face_locations(known_image)

# %%
unknown_image = face_recognition.load_image_file("untitled.jpg")

messi_encoding = face_recognition.face_encodings(known_image)[0]
untitled_encoding = face_recognition.face_encodings(unknown_image)[0]

results = face_recognition.compare_faces([messi_encoding], untitled_encoding)

# %%
print(results)
# Out:
# [True]

# %%
from IPython.display import Image

# Display the image
Image(filename='messi.jpg')

# %%
Image(filename='ronaldo.jpg')

# %%
Image(filename='untitled.jpg')

# %%
ronaldo_image = face_recognition.load_image_file("ronaldo.jpg")
ronaldo_encoding = face_recognition.face_encodings(ronaldo_image)[0]

results_2 = face_recognition.compare_faces([ronaldo_encoding], untitled_encoding)
print(results_2)
# Out:
# [False]

# %%
if results[0] == True:
    print("It's a picture of Messi!")
elif results_2[0] == True :
    print("It's a picture of Ronaldo!")
else:
  print("It's niether a picture of Messi nor ronaldo")
# Out:
# It's a picture of Messi!

# %%
import face_recognition
import cv2
import matplotlib.pyplot as plt

# Load the image
image_path = "messi.jpg"  # Replace "example.jpg" with the path to your image
image = cv2.imread(image_path)

# Convert the image from BGR to RGB (as face_recognition works with RGB images)
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect face landmarks
face_landmarks_list = face_recognition.face_landmarks(rgb_image)

# Draw landmarks on the image
for face_landmarks in face_landmarks_list:
    for facial_feature in face_landmarks.keys():
        for point in face_landmarks[facial_feature]:
            cv2.circle(image, point, 2, (0, 255, 0), -1)  # Draw a green circle at each landmark point

# Display the image with landmarks
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Turn off axis
plt.show()
